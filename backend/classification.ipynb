# %%
import pandas as pd

books = pd.read_csv("cleaned_data.csv")

# %%
books["categories"].value_counts().reset_index()
# Out:
#                     categories  count
# 0                      Fiction   2297
# 1             Juvenile Fiction    467
# 2    Biography & Autobiography    350
# 3                      History    234
# 4           Literary Criticism    139
# ..                         ...    ...
# 498                      Anger      1
# 499            American essays      1
# 500                     Comedy      1
# 501                    Ireland      1
# 502                  Seduction      1
#
# [503 rows x 2 columns]

# %%
books["categories"].value_counts().reset_index().query("count > 50")
# Out:
#                    categories  count
# 0                     Fiction   2297
# 1            Juvenile Fiction    467
# 2   Biography & Autobiography    350
# 3                     History    234
# 4          Literary Criticism    139
# 5                  Philosophy    131
# 6     Comics & Graphic Novels    129
# 7                    Religion    127
# 8                       Drama    101
# 9         Juvenile Nonfiction     84
# 10                    Science     63
# 11                     Poetry     60
# 12       Business & Economics     57
# 13       Literary Collections     56
# 14             Social Science     55

# %%
books[books["categories"] == "Juvenile Fiction"]
# Out:
#              isbn13      isbn10  \
# 30    9780006646006  000664600X
# 83    9780020442608  0020442602
# 91    9780030547744  0030547741
# 92    9780060000141  0060000147
# 93    9780060001537  0060001534
# ...             ...         ...
# 5497  9781596792500  1596792507
# 5511  9781599900056  159990005X
# 5583  9781844580514  1844580512
# 5720  9781930900240  1930900244
# 5743  9781932416374  1932416374
#
#                                                   title  \
# 30                                   Ocean Star Express
# 83                       The voyage of the Dawn Treader
# 91                             Where the Red Fern Grows
# 92                                       Poppy's Return
# 93                                    Diary of a Spider
# ...                                                 ...
# 5497  Sherlock Holmes and the Case of the Hound of t...
# 5511                                    The Drift House
# 5583                               Attack of the Jaguar
# 5720                             The Brothers Lionheart
# 5743                The Very Persistent Gappers of Frip
#
#                                        authors        categories  \
# 30                    Mark Haddon;Peter Sutton  Juvenile Fiction
# 83                         Clive Staples Lewis  Juvenile Fiction
# 91                                Wilson Rawls  Juvenile Fiction
# 92                                         Avi  Juvenile Fiction
# 93                               Doreen Cronin  Juvenile Fiction
# ...                                        ...               ...
# 5497       Arthur Conan Doyle;Malvina G. Vogel  Juvenile Fiction
# 5511                                 Dale Peck  Juvenile Fiction
# 5583                              M. A. Harvey  Juvenile Fiction
# 5720  Astrid Lindgren;Ilon Wikland;Jill Morgan  Juvenile Fiction
# 5743                George Saunders;Lane Smith  Juvenile Fiction
#
#                                               thumbnail  \
# 30    http://books.google.com/books/content?id=I2QZA...
# 83    http://books.google.com/books/content?id=fDD3C...
# 91    http://books.google.com/books/content?id=IHpRw...
# 92    http://books.google.com/books/content?id=XbcMJ...
# 93    http://books.google.com/books/content?id=UWvZo...
# ...                                                 ...
# 5497  http://books.google.com/books/content?id=EWgWP...
# 5511  http://books.google.com/books/content?id=kbwPY...
# 5583  http://books.google.com/books/content?id=3HUdt...
# 5720  http://books.google.com/books/content?id=z2QJA...
# 5743  http://books.google.com/books/content?id=xYJOP...
#
#                                             description  published_year  \
# 30    Joe and his parents are enjoying a summer holi...          2002.0
# 83    The "Dawn Treader" is the first ship Narnia ha...          1970.0
# 91    A young boy living in the Ozarks achieves his ...          2000.0
# 92    There's trouble at Gray House, the girlhood ho...          2006.0
# 93    This is the diary ... of a spider. But don't b...          2005.0
# ...                                                 ...             ...
# 5497  Sherlock Holmes and Dr. Watson travel to the b...          2005.0
# 5511  Sent to stay with their uncle in a ship-like h...          2006.0
# 5583  This training manual for operatives of Xtreme ...          2004.0
# 5720  Two brothers share many adventures after their...          2004.0
# 5743  A novel set in the seaside village of Frip fol...          2006.0
#
#       average_rating  num_pages  ratings_count  \
# 30              3.50       32.0            1.0
# 83              4.09      216.0         2869.0
# 91              4.37      288.0           95.0
# 92              3.99      256.0         1086.0
# 93              4.25       40.0         7903.0
# ...              ...        ...            ...
# 5497            4.51      237.0           28.0
# 5511            3.64      437.0          595.0
# 5583            3.40      125.0            4.0
# 5720            4.36      231.0        19745.0
# 5743            4.11       84.0         2317.0
#
#                                      title_and_subtitle  \
# 30                                   Ocean Star Express
# 83                       The voyage of the Dawn Treader
# 91    Where the Red Fern Grows: The Story of Two Dog...
# 92                                       Poppy's Return
# 93                                    Diary of a Spider
# ...                                                 ...
# 5497  Sherlock Holmes and the Case of the Hound of t...
# 5511                  The Drift House: The First Voyage
# 5583                               Attack of the Jaguar
# 5720                             The Brothers Lionheart
# 5743                The Very Persistent Gappers of Frip
#
#                                      tagged_description
# 30    9780006646006 Joe and his parents are enjoying...
# 83    9780020442608 The "Dawn Treader" is the first ...
# 91    9780030547744 A young boy living in the Ozarks...
# 92    9780060000141 There's trouble at Gray House, t...
# 93    9780060001537 This is the diary ... of a spide...
# ...                                                 ...
# 5497  9781596792500 Sherlock Holmes and Dr. Watson t...
# 5511  9781599900056 Sent to stay with their uncle in...
# 5583  9781844580514 This training manual for operati...
# 5720  9781930900240 Two brothers share many adventur...
# 5743  9781932416374 A novel set in the seaside villa...
#
# [467 rows x 13 columns]

# %%
books[books["categories"] == "Juvenile Nonfiction"]
# Out:
#              isbn13      isbn10                          title  \
# 115   9780060277406  0060277408     The Secret Garden Cookbook
# 116   9780060278427  0060278420                  Laura's Album
# 239   9780060782139  0060782137    Time For Kids: Butterflies!
# 278   9780060882600  0060882603  The Annotated Charlotte's Web
# 461   9780064462044  0064462048    My Little House Crafts Book
# ...             ...         ...                            ...
# 5297  9781580495868  1580495869       The Red Badge of Courage
# 5365  9781586853334  1586853333      The Big Book of Boy Stuff
# 5616  9781857232097  1857232097            The Fires of Heaven
# 5725  9781931414166  1931414165            The Brooklyn Bridge
# 5773  9783791329284  3791329286                 Joseph Cornell
#
#                                authors           categories  \
# 115                         Amy Cotler  Juvenile Nonfiction
# 116                   William Anderson  Juvenile Nonfiction
# 239           Editors of TIME For Kids  Juvenile Nonfiction
# 278                        E. B. White  Juvenile Nonfiction
# 461              Carolyn Strom Collins  Juvenile Nonfiction
# ...                                ...                  ...
# 5297                     Stephen Crane  Juvenile Nonfiction
# 5365                         Bart King  Juvenile Nonfiction
# 5616                     Robert Jordan  Juvenile Nonfiction
# 5725    Elizabeth Mann;Alan Witschonke  Juvenile Nonfiction
# 5773  Joseph Cornell;Alison Baverstock  Juvenile Nonfiction
#
#                                               thumbnail  \
# 115   http://books.google.com/books/content?id=c7E_H...
# 116   http://books.google.com/books/content?id=_zTkq...
# 239   http://books.google.com/books/content?id=OdZxn...
# 278   http://books.google.com/books/content?id=vaYYH...
# 461   http://books.google.com/books/content?id=lTzrs...
# ...                                                 ...
# 5297  http://books.google.com/books/content?id=lN1ga...
# 5365  http://books.google.com/books/content?id=08Ilm...
# 5616  http://books.google.com/books/content?id=4HyfQ...
# 5725  http://books.google.com/books/content?id=s28MA...
# 5773  http://books.google.com/books/content?id=KnO8A...
#
#                                             description  published_year  \
# 115   Frances Hodgson Burnett's The Secret Garden de...          1999.0
# 116   Though best known as the author of the Little ...          1998.0
# 239   Butterflies There are 20,000 different kinds o...          2006.0
# 278   Charlotte's Web, one of America's best-loved c...          2006.0
# 461   Make the same pioneer crafts that Laura did! I...          1998.0
# ...                                                 ...             ...
# 5297  As he faces battle in the Civil War for the fi...          2004.0
# 5365  There's this boy. Let's say he's somewhere bet...          2004.0
# 5616  The fifth book in Robert Jordan's internationa...          1994.0
# 5725  Describes the construction of the Brooklyn Bri...          2006.0
# 5773  Provides an introduction to the American artis...          2003.0
#
#       average_rating  num_pages  ratings_count  \
# 115             4.28      128.0          142.0
# 116             4.30       80.0          713.0
# 239             4.00       32.0           20.0
# 278             4.16      320.0           41.0
# 461             4.05       64.0           56.0
# ...              ...        ...            ...
# 5297            3.23      170.0        74477.0
# 5365            4.24      292.0          141.0
# 5616            4.15      912.0       106302.0
# 5725            4.44       46.0           35.0
# 5773            4.06       27.0           31.0
#
#                                      title_and_subtitle  \
# 115   The Secret Garden Cookbook: Recipes Inspired b...
# 116   Laura's Album: A Remembrance Scrapbook of Laur...
# 239                         Time For Kids: Butterflies!
# 278                       The Annotated Charlotte's Web
# 461   My Little House Crafts Book: 18 Projects from ...
# ...                                                 ...
# 5297                           The Red Badge of Courage
# 5365                          The Big Book of Boy Stuff
# 5616                                The Fires of Heaven
# 5725                                The Brooklyn Bridge
# 5773                   Joseph Cornell: Secrets in a Box
#
#                                      tagged_description
# 115   9780060277406 Frances Hodgson Burnett's The Se...
# 116   9780060278427 Though best known as the author ...
# 239   9780060782139 Butterflies There are 20,000 dif...
# 278   9780060882600 Charlotte's Web, one of America'...
# 461   9780064462044 Make the same pioneer crafts tha...
# ...                                                 ...
# 5297  9781580495868 As he faces battle in the Civil ...
# 5365  9781586853334 There's this boy. Let's say he's...
# 5616  9781857232097 The fifth book in Robert Jordan'...
# 5725  9781931414166 Describes the construction of th...
# 5773  9783791329284 Provides an introduction to the ...
#
# [84 rows x 13 columns]

# %%
category_mapping = {'Fiction' : "Fiction",
 'Juvenile Fiction': "Children's Fiction",
 'Biography & Autobiography': "Nonfiction",
 'History': "Nonfiction",
 'Literary Criticism': "Nonfiction",
 'Philosophy': "Nonfiction",
 'Religion': "Nonfiction",
 'Comics & Graphic Novels': "Fiction",
 'Drama': "Fiction",
 'Juvenile Nonfiction': "Children's Nonfiction",
 'Science': "Nonfiction",
 'Poetry': "Fiction"}

books["simple_categories"] = books["categories"].map(category_mapping)

# %%
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5784  9788173031014  8173031010
# 5785  9788179921623  817992162X
# 5786  9788185300535  8185300534
# 5787  9789027712059  9027712050
# 5788  9789042003408  9042003405
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5784                                Journey to the East
# 5785  The Monk Who Sold His Ferrari: A Fable About F...
# 5786                                          I Am that
# 5787                           The Berlin Phenomenology
# 5788                          'I'm Telling You Stories'
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                                   Sidney Sheldon
# 3                              Clive Staples Lewis
# 4                              Clive Staples Lewis
# ...                                            ...
# 5784                                 Hermann Hesse
# 5785                                  Robin Sharma
# 5786  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 5787                 Georg Wilhelm Friedrich Hegel
# 5788                        Helena Grice;Tim Woods
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                           Fiction
# 3                    Christian life
# 4                    Christian life
# ...                             ...
# 5784              Adventure stories
# 5785               Health & Fitness
# 5786                     Philosophy
# 5787                        History
# 5788             Literary Criticism
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 3     http://books.google.com/books/content?id=XhQ5X...
# 4     http://books.google.com/books/content?id=Kk-uV...
# ...                                                 ...
# 5784  http://books.google.com/books/content?id=rq6JP...
# 5785  http://books.google.com/books/content?id=c_7mf...
# 5786  http://books.google.com/books/content?id=Fv_JP...
# 5787  http://books.google.com/books/content?id=Vy7Sk...
# 5788  http://books.google.com/books/content?id=2lVyR...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 3     Lewis' work on the nature of love divides love...          2002.0
# 4     "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
# ...                                                 ...             ...
# 5784  This book tells the tale of a man who goes on ...          2002.0
# 5785  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 5786  This collection of the timeless teachings of o...          1999.0
# 5787  Since the three volume edition ofHegel's Philo...          1981.0
# 5788  This is a jubilant and rewarding collection of...          1998.0
#
#       average_rating  num_pages  ratings_count  \
# 0               3.85      247.0          361.0
# 1               3.83      241.0         5164.0
# 2               3.93      512.0        29532.0
# 3               4.15      170.0        33684.0
# 4               4.09      176.0        37569.0
# ...              ...        ...            ...
# 5784            3.70      175.0           24.0
# 5785            3.82      198.0         1568.0
# 5786            4.51      531.0          104.0
# 5787            0.00      210.0            0.0
# 5788            3.70      136.0           10.0
#
#                                      title_and_subtitle  \
# 0                                                Gilead
# 1                                 Spider's Web: A Novel
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5784                                Journey to the East
# 5785  The Monk Who Sold His Ferrari: A Fable About F...
# 5786     I Am that: Talks with Sri Nisargadatta Maharaj
# 5787                           The Berlin Phenomenology
# 5788  'I'm Telling You Stories': Jeanette Winterson ...
#
#                                      tagged_description simple_categories
# 0     9780002005883 A NOVEL THAT READERS and critics...           Fiction
# 1     9780002261982 A new 'Christie for Christmas' -...               NaN
# 2     9780006178736 A memorable, mesmerizing heroine...           Fiction
# 3     9780006280897 Lewis' work on the nature of lov...               NaN
# 4     9780006280934 "In The Problem of Pain, C.S. Le...               NaN
# ...                                                 ...               ...
# 5784  9788173031014 This book tells the tale of a ma...               NaN
# 5785  9788179921623 Wisdom to Create a Life of Passi...               NaN
# 5786  9788185300535 This collection of the timeless ...        Nonfiction
# 5787  9789027712059 Since the three volume edition o...        Nonfiction
# 5788  9789042003408 This is a jubilant and rewarding...        Nonfiction
#
# [5789 rows x 14 columns]

# %%
books[~(books["simple_categories"].isna())]
# Out:
#              isbn13      isbn10                      title  \
# 0     9780002005883  0002005883                     Gilead
# 2     9780006178736  0006178731             Rage of angels
# 8     9780006482079  0006482074        Warhost of Vastmark
# 30    9780006646006  000664600X         Ocean Star Express
# 47    9780007121014  0007121016         Taken at the Flood
# ...             ...         ...                        ...
# 5779  9784770028969  4770028962         Coin Locker Babies
# 5780  9788122200850  8122200850           Cry, the Peacock
# 5786  9788185300535  8185300534                  I Am that
# 5787  9789027712059  9027712050   The Berlin Phenomenology
# 5788  9789042003408  9042003405  'I'm Telling You Stories'
#
#                                            authors          categories  \
# 0                               Marilynne Robinson             Fiction
# 2                                   Sidney Sheldon             Fiction
# 8                                      Janny Wurts             Fiction
# 30                        Mark Haddon;Peter Sutton    Juvenile Fiction
# 47                                 Agatha Christie             Fiction
# ...                                            ...                 ...
# 5779                                           村上龍             Fiction
# 5780                                   Anita Desai             Fiction
# 5786  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit          Philosophy
# 5787                 Georg Wilhelm Friedrich Hegel             History
# 5788                        Helena Grice;Tim Woods  Literary Criticism
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 8     http://books.google.com/books/content?id=uOL0f...
# 30    http://books.google.com/books/content?id=I2QZA...
# 47    http://books.google.com/books/content?id=3gWlx...
# ...                                                 ...
# 5779  http://books.google.com/books/content?id=87DJw...
# 5780  http://books.google.com/books/content?id=_QKwV...
# 5786  http://books.google.com/books/content?id=Fv_JP...
# 5787  http://books.google.com/books/content?id=Vy7Sk...
# 5788  http://books.google.com/books/content?id=2lVyR...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 8     Tricked once more by his wily half-brother, Ly...          1995.0
# 30    Joe and his parents are enjoying a summer holi...          2002.0
# 47    A Few Weeks After Marrying An Attractive Young...          2002.0
# ...                                                 ...             ...
# 5779  Rescued from the lockers in which they were le...          2002.0
# 5780  This book is the story of a young girl obsesse...          1980.0
# 5786  This collection of the timeless teachings of o...          1999.0
# 5787  Since the three volume edition ofHegel's Philo...          1981.0
# 5788  This is a jubilant and rewarding collection of...          1998.0
#
#       average_rating  num_pages  ratings_count  \
# 0               3.85      247.0          361.0
# 2               3.93      512.0        29532.0
# 8               4.03      522.0         2966.0
# 30              3.50       32.0            1.0
# 47              3.71      352.0         8852.0
# ...              ...        ...            ...
# 5779            3.75      393.0         5560.0
# 5780            3.22      218.0          134.0
# 5786            4.51      531.0          104.0
# 5787            0.00      210.0            0.0
# 5788            3.70      136.0           10.0
#
#                                      title_and_subtitle  \
# 0                                                Gilead
# 2                                        Rage of angels
# 8                                   Warhost of Vastmark
# 30                                   Ocean Star Express
# 47                                   Taken at the Flood
# ...                                                 ...
# 5779                                 Coin Locker Babies
# 5780                                   Cry, the Peacock
# 5786     I Am that: Talks with Sri Nisargadatta Maharaj
# 5787                           The Berlin Phenomenology
# 5788  'I'm Telling You Stories': Jeanette Winterson ...
#
#                                      tagged_description   simple_categories
# 0     9780002005883 A NOVEL THAT READERS and critics...             Fiction
# 2     9780006178736 A memorable, mesmerizing heroine...             Fiction
# 8     9780006482079 Tricked once more by his wily ha...             Fiction
# 30    9780006646006 Joe and his parents are enjoying...  Children's Fiction
# 47    9780007121014 A Few Weeks After Marrying An At...             Fiction
# ...                                                 ...                 ...
# 5779  9784770028969 Rescued from the lockers in whic...             Fiction
# 5780  9788122200850 This book is the story of a youn...             Fiction
# 5786  9788185300535 This collection of the timeless ...          Nonfiction
# 5787  9789027712059 Since the three volume edition o...          Nonfiction
# 5788  9789042003408 This is a jubilant and rewarding...          Nonfiction
#
# [4182 rows x 14 columns]

# %%
from transformers import pipeline

fiction_categories = ["Fiction", "Nonfiction"]

pipe = pipeline("zero-shot-classification",
                model="facebook/bart-large-mnli",
                device=-1)
# Out:
# Device set to use cpu

# %%
sequence = books.loc[books["simple_categories"] == "Fiction", "description"].reset_index(drop=True)[0]

# %%
pipe(sequence, fiction_categories)
# Out:
# {'sequence': 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world has to offer. At its heart is a tale of the sacred bonds between fathers and sons, pitch-perfect in style and story, set to dazzle critics and readers alike.',
#  'labels': ['Fiction', 'Nonfiction'],
#  'scores': [0.8438267111778259, 0.15617331862449646]}

# %%
#now let's get the maximum lebel books
import numpy as np

max_index = np.argmax(pipe(sequence, fiction_categories)["scores"])
max_label = pipe(sequence, fiction_categories)["labels"][max_index]
max_label
# Out:
# 'Fiction'

# %%
def generate_predictions(sequence, categories):
    predictions = pipe(sequence, categories)
    max_index = np.argmax(predictions["scores"])
    max_label = predictions["labels"][max_index]
    return max_label

# %%
from tqdm import tqdm

actual_cats = []
predicted_cats = []

for i in tqdm(range(0, 300)):
    sequence = books.loc[books["simple_categories"] == "Fiction", "description"].reset_index(drop=True)[i]
    predicted_cats += [generate_predictions(sequence, fiction_categories)]
    actual_cats += ["Fiction"]
# Out:
# 100%|██████████| 300/300 [15:42<00:00,  3.14s/it]

# %%
for i in tqdm(range(0, 300)):
    sequence = books.loc[books["simple_categories"] == "Nonfiction", "description"].reset_index(drop=True)[i]
    predicted_cats += [generate_predictions(sequence, fiction_categories)]
    actual_cats += ["Nonfiction"]
# Out:
# 100%|██████████| 300/300 [15:20<00:00,  3.07s/it]

# %%
predictions_df = pd.DataFrame({"actual_categories": actual_cats, "predicted_categories": predicted_cats})

# %%
predictions_df
# Out:
#     actual_categories predicted_categories
# 0             Fiction              Fiction
# 1             Fiction              Fiction
# 2             Fiction              Fiction
# 3             Fiction           Nonfiction
# 4             Fiction              Fiction
# ..                ...                  ...
# 595        Nonfiction           Nonfiction
# 596        Nonfiction              Fiction
# 597        Nonfiction           Nonfiction
# 598        Nonfiction           Nonfiction
# 599        Nonfiction           Nonfiction
#
# [600 rows x 2 columns]

# %%
predictions_df["correct_prediction"] = (
    np.where(predictions_df["actual_categories"] == predictions_df["predicted_categories"], 1, 0)
)

# %%
predictions_df["correct_prediction"].sum() / len(predictions_df)
# Out:
# np.float64(0.77)

# %%
isbns = []
predicted_cats = []

missing_cats = books.loc[books["simple_categories"].isna(), ["isbn13", "description"]].reset_index(drop=True)

# %%
for i in tqdm(range(0, len(missing_cats))):
    sequence = missing_cats["description"][i]
    predicted_cats += [generate_predictions(sequence, fiction_categories)]
    isbns += [missing_cats["isbn13"][i]]
# Out:
# 100%|██████████| 1607/1607 [1:12:23<00:00,  2.70s/it]

# %%
missing_predicted_df = pd.DataFrame({"isbn13": isbns, "predicted_categories": predicted_cats})

# %%
missing_predicted_df
# Out:
#              isbn13 predicted_categories
# 0     9780002261982              Fiction
# 1     9780006280897           Nonfiction
# 2     9780006280934           Nonfiction
# 3     9780006380832           Nonfiction
# 4     9780006470229              Fiction
# ...             ...                  ...
# 1602  9788125026600           Nonfiction
# 1603  9788171565641              Fiction
# 1604  9788172235222              Fiction
# 1605  9788173031014           Nonfiction
# 1606  9788179921623              Fiction
#
# [1607 rows x 2 columns]

# %%
books = pd.merge(books, missing_predicted_df, on="isbn13", how="left")
books["simple_categories"] = np.where(books["simple_categories"].isna(), books["predicted_categories"], books["simple_categories"])
books = books.drop(columns = ["predicted_categories"])

# %%
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5784  9788173031014  8173031010
# 5785  9788179921623  817992162X
# 5786  9788185300535  8185300534
# 5787  9789027712059  9027712050
# 5788  9789042003408  9042003405
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5784                                Journey to the East
# 5785  The Monk Who Sold His Ferrari: A Fable About F...
# 5786                                          I Am that
# 5787                           The Berlin Phenomenology
# 5788                          'I'm Telling You Stories'
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                                   Sidney Sheldon
# 3                              Clive Staples Lewis
# 4                              Clive Staples Lewis
# ...                                            ...
# 5784                                 Hermann Hesse
# 5785                                  Robin Sharma
# 5786  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 5787                 Georg Wilhelm Friedrich Hegel
# 5788                        Helena Grice;Tim Woods
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                           Fiction
# 3                    Christian life
# 4                    Christian life
# ...                             ...
# 5784              Adventure stories
# 5785               Health & Fitness
# 5786                     Philosophy
# 5787                        History
# 5788             Literary Criticism
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 3     http://books.google.com/books/content?id=XhQ5X...
# 4     http://books.google.com/books/content?id=Kk-uV...
# ...                                                 ...
# 5784  http://books.google.com/books/content?id=rq6JP...
# 5785  http://books.google.com/books/content?id=c_7mf...
# 5786  http://books.google.com/books/content?id=Fv_JP...
# 5787  http://books.google.com/books/content?id=Vy7Sk...
# 5788  http://books.google.com/books/content?id=2lVyR...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 3     Lewis' work on the nature of love divides love...          2002.0
# 4     "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
# ...                                                 ...             ...
# 5784  This book tells the tale of a man who goes on ...          2002.0
# 5785  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 5786  This collection of the timeless teachings of o...          1999.0
# 5787  Since the three volume edition ofHegel's Philo...          1981.0
# 5788  This is a jubilant and rewarding collection of...          1998.0
#
#       average_rating  num_pages  ratings_count  \
# 0               3.85      247.0          361.0
# 1               3.83      241.0         5164.0
# 2               3.93      512.0        29532.0
# 3               4.15      170.0        33684.0
# 4               4.09      176.0        37569.0
# ...              ...        ...            ...
# 5784            3.70      175.0           24.0
# 5785            3.82      198.0         1568.0
# 5786            4.51      531.0          104.0
# 5787            0.00      210.0            0.0
# 5788            3.70      136.0           10.0
#
#                                      title_and_subtitle  \
# 0                                                Gilead
# 1                                 Spider's Web: A Novel
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5784                                Journey to the East
# 5785  The Monk Who Sold His Ferrari: A Fable About F...
# 5786     I Am that: Talks with Sri Nisargadatta Maharaj
# 5787                           The Berlin Phenomenology
# 5788  'I'm Telling You Stories': Jeanette Winterson ...
#
#                                      tagged_description simple_categories
# 0     9780002005883 A NOVEL THAT READERS and critics...           Fiction
# 1     9780002261982 A new 'Christie for Christmas' -...           Fiction
# 2     9780006178736 A memorable, mesmerizing heroine...           Fiction
# 3     9780006280897 Lewis' work on the nature of lov...        Nonfiction
# 4     9780006280934 "In The Problem of Pain, C.S. Le...        Nonfiction
# ...                                                 ...               ...
# 5784  9788173031014 This book tells the tale of a ma...        Nonfiction
# 5785  9788179921623 Wisdom to Create a Life of Passi...           Fiction
# 5786  9788185300535 This collection of the timeless ...        Nonfiction
# 5787  9789027712059 Since the three volume edition o...        Nonfiction
# 5788  9789042003408 This is a jubilant and rewarding...        Nonfiction
#
# [5789 rows x 14 columns]

# %%
books[books["categories"].str.lower().isin([
    "romance",
    "science fiction",
    "scifi",
    "fantasy",
    "horror",
    "mystery",
    "thriller",
    "comedy",
    "crime",
    "historical"
])]
# Out:
#              isbn13      isbn10                                     title  \
# 24    9780006513087  0006513085                                   Gravity
# 502   9780099410355  0099410354                                   Traitor
# 505   9780099422341  0099422344                            Yeats is Dead!
# 518   9780099446729  0099446723                            Blackwood Farm
# 1183  9780261102422  0261102427                          The Silmarillion
# 1555  9780340837955  0340837950                Stranger in a Strange Land
# 1559  9780345251220  0345251229                      Visions from Nowhere
# 2321  9780439405607  0439405602       Guardians of Ga'Hoole #4: The Siege
# 3147  9780575075597  0575075597                                    Replay
# 3166  9780590254762  0590254766      The lion, the witch and the wardrobe
# 3678  9780739423851  0739423851                           Wizard's Castle
# 3680  9780739439708  0739439707                              Time Quartet
# 3973  9780760728505  076072850X              20,000 Leagues Under the Sea
# 5008  9781416502043  1416502041  The Voyage of the Jerle Shannara Trilogy
# 5549  9781841494081  1841494089            The Darkness that Comes Before
# 5615  9781857231359  185723135X                            Use of Weapons
# 5632  9781857989342  1857989341                       The Gods Themselves
#
#                         authors       categories  \
# 24               Tess Gerritsen  Science fiction
# 502     Matthew Woodring Stover  Science fiction
# 505             Joseph O'Connor           Comedy
# 518                   Anne Rice           Horror
# 1183  John Ronald Reuel Tolkien          Fantasy
# 1555         Robert A. Heinlein  Science fiction
# 1559              William Arrow  Science fiction
# 2321              Kathryn Lasky          Fantasy
# 3147               Ken Grimwood          Fantasy
# 3166        Clive Staples Lewis          Fantasy
# 3678          Diana Wynne Jones          Fantasy
# 3680          Madeleine L'Engle  Science fiction
# 3973                Jules Verne  Science fiction
# 5008               Terry Brooks          Fantasy
# 5549            R. Scott Bakker          Fantasy
# 5615                 Iain Banks  Science fiction
# 5632               Isaac Asimov  Science fiction
#
#                                               thumbnail  \
# 24    http://books.google.com/books/content?id=KI66c...
# 502   http://books.google.com/books/content?id=VbICO...
# 505   http://books.google.com/books/content?id=DrE3I...
# 518   http://books.google.com/books/content?id=cIn8T...
# 1183  http://books.google.com/books/content?id=22ePu...
# 1555  http://books.google.com/books/content?id=ZQhiP...
# 1559                                                NaN
# 2321                                                NaN
# 3147  http://books.google.com/books/content?id=9vmNP...
# 3166                                                NaN
# 3678  http://books.google.com/books/content?id=hB7hA...
# 3680                                                NaN
# 3973                                                NaN
# 5008  http://books.google.com/books/content?id=jqVsA...
# 5549  http://books.google.com/books/content?id=BG8qG...
# 5615                                                NaN
# 5632  http://books.google.com/books/content?id=8ClIP...
#
#                                             description  published_year  \
# 24    Emma Watson a research physician has been trai...          2004.0
# 502   From the depths of catastrophe, a glimmer of h...          2002.0
# 505   In aid of Amnesty International, this is a bri...          2002.0
# 518   Lestat Is Back, Saviour And Demon, Presiding O...          2003.0
# 1183  Tolkien's Silmarillion is the core work of the...          1999.0
# 1555  Epic, entertaining, Stranger in a Strange Land...          2005.0
# 1559  The first novel in the series, "Return to the ...          1976.0
# 2321  The war between the evil group led by Soren's ...          2003.0
# 3147  At forty-three Jeff Winston is tired of his lo...          2005.0
# 3166  Four English school children enter the magic l...          1995.0
# 3678  Howl's moving castle - Eldest of three sisters...          2002.0
# 3680  Blending magic with quantum physics, Madeleine...          2003.0
# 3973  Retells the adventures of a French professor a...          2002.0
# 5008  When the body of a half-drowned elf is found f...          2004.0
# 5549  A score of centuries has passed since the Firs...          2005.0
# 5615  The man known as Cheradenine Zakalwe was one o...          1992.0
# 5632  In the year 2100, mankind on Earth, settlers i...          2000.0
#
#       average_rating  num_pages  ratings_count  \
# 24              4.04      342.0         8024.0
# 502             4.00      320.0         6765.0
# 505             3.39      298.0           34.0
# 518             3.86      774.0        26145.0
# 1183            3.91      384.0          253.0
# 1555            3.92      672.0          563.0
# 1559            3.23      183.0           10.0
# 2321            4.10      203.0         8964.0
# 3147            4.16      272.0          412.0
# 3166            4.21      189.0          860.0
# 3678            4.44      376.0          439.0
# 3680            4.35      646.0          165.0
# 3973            3.88      394.0       135778.0
# 5008            4.26     1260.0           84.0
# 5549            3.79      638.0          317.0
# 5615            4.19      411.0        30779.0
# 5632            4.09      288.0        41304.0
#
#                                     title_and_subtitle  \
# 24                                             Gravity
# 502                                            Traitor
# 505   Yeats is Dead!: A Novel by Fifteen Irish Writers
# 518                                     Blackwood Farm
# 1183                                  The Silmarillion
# 1555                        Stranger in a Strange Land
# 1559                              Visions from Nowhere
# 2321               Guardians of Ga'Hoole #4: The Siege
# 3147                                            Replay
# 3166              The lion, the witch and the wardrobe
# 3678                                   Wizard's Castle
# 3680                                      Time Quartet
# 3973                      20,000 Leagues Under the Sea
# 5008          The Voyage of the Jerle Shannara Trilogy
# 5549                    The Darkness that Comes Before
# 5615                                    Use of Weapons
# 5632                               The Gods Themselves
#
#                                      tagged_description simple_categories
# 24    9780006513087 Emma Watson a research physician...        Nonfiction
# 502   9780099410355 From the depths of catastrophe, ...           Fiction
# 505   9780099422341 In aid of Amnesty International,...           Fiction
# 518   9780099446729 Lestat Is Back, Saviour And Demo...           Fiction
# 1183  9780261102422 Tolkien's Silmarillion is the co...           Fiction
# 1555  9780340837955 Epic, entertaining, Stranger in ...           Fiction
# 1559  9780345251220 The first novel in the series, "...           Fiction
# 2321  9780439405607 The war between the evil group l...           Fiction
# 3147  9780575075597 At forty-three Jeff Winston is t...           Fiction
# 3166  9780590254762 Four English school children ent...        Nonfiction
# 3678  9780739423851 Howl's moving castle - Eldest of...           Fiction
# 3680  9780739439708 Blending magic with quantum phys...           Fiction
# 3973  9780760728505 Retells the adventures of a Fren...           Fiction
# 5008  9781416502043 When the body of a half-drowned ...           Fiction
# 5549  9781841494081 A score of centuries has passed ...        Nonfiction
# 5615  9781857231359 The man known as Cheradenine Zak...        Nonfiction
# 5632  9781857989342 In the year 2100, mankind on Ear...           Fiction

# %%
books.to_csv("categoriesed_books.csv", index=False)
